# %% [markdown]
# <a href="https://colab.research.google.com/github/NadhaKaleel/northstar-analytics/blob/main/notebooks/04_mangodb_development.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
